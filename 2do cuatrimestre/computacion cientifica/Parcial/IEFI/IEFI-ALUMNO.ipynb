# %% [markdown]
# ![logo_ies.png](attachment:logo_ies.png)

# %% [markdown]
# # COMPUTACIÓN CIENTÍFICA
#
# ## PRIMERA INSTANCIA EVALUATIVA
#
# ### TEMA A
#
# Prof. Erica Bongiovanni

# %% [markdown]
# ## INDICACIONES:
#
# - Para resolver puede utilizar más de una celda si es necesario.
# - Escriba comentarios con # para facilitar la lectura de las operaciones que realiza.
#
# **ENVÍO DEL EXAMEN**
#
# Debe subir este archivo, con los ejercicios resueltos, en la misma página donde los descargó.

# %% [markdown]
# ## EJERCICIOS

# %% [markdown]
# ### Ejercicio 1
# En la siguiente celda importe todas las librerías que necesite, puede agregarlas a medida que las vaya necesitando.

# %%
# Escriba aquí su código
import numpy as np
import pandas as pd
import matplotlib.pyplot as mp

# %% [markdown]
# ### Ejercicio 2
# En la carpeta datos encontrará el archivo movie.csv que contiene información real sobre películas. Cárguelo en un dataframe llamado **df_movies**.

# %%
# Escriba aquí su código
df_movies=pd.read_csv("datos/movie.csv")

# %% [markdown]
# ### Ejercicio 3
# Muestre las 10 primeras filas

# %%
# Escriba aquí su código
df_movies.head(10)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
# 7  Color       Nathan Greno                   324.0     100.0
# 8  Color        Joss Whedon                   635.0     141.0
# 9  Color        David Yates                   375.0     153.0
#
#    director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                      0.0                   855.0   Joel David Moore
# 1                    563.0                  1000.0      Orlando Bloom
# 2                      0.0                   161.0       Rory Kinnear
# ...

# %% [markdown]
# ### Ejercicio 4
# Obtenga una lista con los nombres de todas las columnas del dataframe, guárdelas con el nombre lst_columnas

# %%
# se adjuntará el archivo con todas las columnas
lst_columnas=pd.Series(df_movies.columns)
lst_columnas
# Out:
# 0                         color
# 1                 director_name
# 2        num_critic_for_reviews
# 3                      duration
# 4       director_facebook_likes
# 5        actor_3_facebook_likes
# 6                  actor_2_name
# 7        actor_1_facebook_likes
# 8                         gross
# 9                        genres
# 10                 actor_1_name
# 11                  movie_title
# 12              num_voted_users
# 13    cast_total_facebook_likes
# 14                 actor_3_name
# 15         facenumber_in_poster
# 16                plot_keywords
# 17              movie_imdb_link
# 18         num_user_for_reviews
# 19                     language
# 20                      country
# 21               content_rating
# 22                       budget
# 23                   title_year
# 24       actor_2_facebook_likes
# 25                   imdb_score
# 26                 aspect_ratio
# 27         movie_facebook_likes
# 28                    ganancias
# ...

# %% [markdown]
# ### Ejercicio 5
# Cuántas filas tiene el dataframe? Guarde el resultado en la variable n_filas y muestre el resultado.

# %%
# Escriba aquí su código
n_filas= df_movies.shape[0]
print(f"El dataframe tiene {n_filas} filas")
# Out:
# El dataframe tiene 4916 filas

# %% [markdown]
# ### Ejercicio 6
#
# Debe quitar la columna **color** del  df_movies

# %%
# Escriba aquí su código
df_movies=df_movies.drop(columns="color")

# %% [markdown]
# ### Ejercicio 7
# Cree la lista lst_columnas2 con los nombres de las columnas actuales de df_movies

# %%
# Escriba aquí su código
columnas=pd.Series(df_movies.columns)
columnas
# Out:
# 0                         color
# 1                 director_name
# 2        num_critic_for_reviews
# 3                      duration
# 4       director_facebook_likes
# 5        actor_3_facebook_likes
# 6                  actor_2_name
# 7        actor_1_facebook_likes
# 8                         gross
# 9                        genres
# 10                 actor_1_name
# 11                  movie_title
# 12              num_voted_users
# 13    cast_total_facebook_likes
# 14                 actor_3_name
# 15         facenumber_in_poster
# 16                plot_keywords
# 17              movie_imdb_link
# 18         num_user_for_reviews
# 19                     language
# 20                      country
# 21               content_rating
# 22                       budget
# 23                   title_year
# 24       actor_2_facebook_likes
# 25                   imdb_score
# 26                 aspect_ratio
# 27         movie_facebook_likes
# dtype: object

# %% [markdown]
# ### Ejercicio 8
#
# La columna 'director_name' indica el nombre del director de cada película.
# Muestre una "lista" con los nombres de cada uno de los directores, cada uno debe figurar una única vez.
# Guárdelo como **lista_directores** y muéstrela.

# %%
# Escriba aquí su código
lista_directores= pd.Series(df_movies.director_name.unique())
# Al ser una lista extensa se la guardará en un archivo que se adjuntará con el nombre de "lista_directores" y se adjuntará
# en la entrega.
lista_directores.to_csv("datos/lista_directores.xls", sep= "\t")
lista_directores
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 2393     Neill Dela Llana
# 2394      Anthony Vallone
# 2395          Scott Smith
# 2396     Benjamin Roberds
# 2397          Daniel Hsia
# Length: 2398, dtype: object

# %% [markdown]
# ### Ejercicio 9
#
# Liste las películas del director 'Christopher Nolan' y guarde el resultado en n_nolan, grabe los datos en un archivo dentro de la carpeta "datos" en el archivo "Ejercicio09.xls" y muestre el resultado.

# %%
n_nolan=df_movies[df_movies.director_name=="Christopher Nolan"]
n_nolan.to_csv("datos/Ejercicio09.xls", sep= "\t")

# %% [markdown]
# ### Ejercicio 10
#
# Cuántas películas del director 'James Cameron' hay en el dataframe? Guarde el resultado en **n_cameron** y muestre el resultado

# %%
# Escriba aquí su código
n_cameron=df_movies[df_movies.director_name=="James Cameron"].shape[0]
n_cameron
print(f"Hay {n_cameron} peliculas en el dataframe dirigidas por el director James Cameron")
# Out:
# Hay 7 peliculas en el dataframe dirigidas por el director James Cameron

# %% [markdown]
# ### Ejercicio 11
# Cuántas  películas sin  nombre de director hay?
#
# Guarde el resultado como n_NAN_directores

# %%
# Escriba aquí su código
n_NAN_directores=df_movies[df_movies.director_name=="NAN"].shape[0]
n_NAN_directores
print(f"Hay {n_NAN_directores} peliculas sin nombre de director")
# Out:
# Hay 0 peliculas sin nombre de director

# %% [markdown]
# ### Ejercicio 12
#
# Cuántas películas ha dirigido **cada** director?  Es decir queremos una serie o dataframe donde figure el nombre de cada director y la cantidad de películas que le corresponde.
#
# Guarde la serie de datos como **qpelisxdirector**

# %%
# Escriba aquí su código
qpelisxdirector= pd.Series(df_movies.director_name.value_counts())
# Al ser una lista extensa se la guardará en un archivo que se adjuntará con el nombre de "qpelisxdirector" y se adjuntará
# en la entrega.
qpelisxdirector.to_csv("datos/qpelisxdirector.xls", sep= "\t")
qpelisxdirector
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Clint Eastwood      20
# Martin Scorsese     20
# Spike Lee           16
#                     ..
# Lenny Abrahamson     1
# Igor Kovalyov        1
# James Manera         1
# Anna Boden           1
# Stanton Barrett      1
# Name: director_name, Length: 2397, dtype: int64

# %% [markdown]
# ### Ejercicio 13
#
# La columna duration indica la duración en minutos.
#
# Cuál es la duración promedio entre todas las películas?
#
# Guárdelo como **duracion_prom**

# %%
# Escriba aquí su código
duracion_prom=df_movies.duration.mean()
duracion_prom
print(f"La duracion promedio entre todas las peliculas es de {format(duracion_prom,'0.2f')} minutos")
# Out:
# La duracion promedio entre todas las peliculas es de 107.09 minutos

# %% [markdown]
# ### Ejercicio 14
#
# En la columna 'actor_1_name' figura el nombre del "primer actor" de cada película.
#
# Obtenga una lista, serie o dataframe con el nombre del primer actor (actor_1_name) y de cada una de las películas (movie_title) del diretor James Cameron y guárdela como **cameron_actor1**

# %%
# Escriba aquí su código
PeliculasCameron= df_movies[df_movies.director_name=="James Cameron"]
PeliculasCameron
cameron_actor1=PeliculasCameron[["actor_1_name","movie_title"]]
cameron_actor1
# Out:
#            actor_1_name                 movie_title
# 0           CCH Pounder                      Avatar
# 26    Leonardo DiCaprio                     Titanic
# 285          Joe Morton  Terminator 2: Judgment Day
# 288    Jamie Lee Curtis                   True Lies
# 599       Michael Biehn                   The Abyss
# 2455      Michael Biehn                      Aliens
# 3508      Michael Biehn              The Terminator

# %% [markdown]
# ### Ejercicio 15
# Ahora cuente cuántas veces aparece cada actor en el listado de primeros actores de James Cameron.
# Guárdelo como **qcameron_actor1**

# %%
# Escriba aquí su código
PeliculasCameron= df_movies[df_movies.director_name=="James Cameron"]
PeliculasCameron
qcameron_actor1=PeliculasCameron["actor_1_name"].value_counts()
qcameron_actor1
# Out:
# Michael Biehn        3
# Leonardo DiCaprio    1
# CCH Pounder          1
# Jamie Lee Curtis     1
# Joe Morton           1
# Name: actor_1_name, dtype: int64

# %% [markdown]
# ### Ejercicio 16
# La columna **budget** corresponde al **Presupuesto**
#
# Cree un DataFrame de nombre **df_10_presupuesto** con las 10 peĺículas de mayor presupuesto de la historia, debe mostrar el nombre de la película ('movie_title'), el nombre del director ('director_name') y el presupuesto ('budget')y estar ordenada de mayor a menor valor del presupuesto.

# %%
# Escriba aquí su código
df_10_presupuesto= df_movies.sort_values("budget", ascending=False).head(10)
df_10_presupuesto[["movie_title","director_name","budget"]]
# Out:
#                  movie_title    director_name        budget
# 3787          Lady Vengeance   Chan-wook Park  4.200000e+09
# 2955                Fateless     Lajos Koltai  2.500000e+09
# 2294       Princess Mononoke   Hayao Miyazaki  2.400000e+09
# 2305                Steamboy  Katsuhiro Ôtomo  2.127520e+09
# 3361                   Akira  Katsuhiro Ôtomo  1.100000e+09
# 4440           Godzilla 2000    Takao Okawara  1.000000e+09
# 3779                   Tango     Carlos Saura  7.000000e+08
# 3023  Kabhi Alvida Naa Kehna      Karan Johar  7.000000e+08
# 3216                   Kites      Anurag Basu  6.000000e+08
# 1325               Red Cliff         John Woo  5.536320e+08

# %% [markdown]
# ### Ejercicio 17
#
# La columna **budget** corresponde al **Presupuesto** y la columna **gross** corresponde a los **ingresos**, queremos agregar una columna al DataFrame donde calculemos las **ganancias** (que se calcularía como ingresos menos presupuesto). Llámela ganancias y agréguela a df_movies.
#
# Para finalizar guarde las columnas movie_title, director_name, budget, gross y ganancias como df_money y muestre los 5 primeros elementos

# %%
# Escriba aquí su código
df_movies["ganancias"]= df_movies.gross - df_movies.budget

# %%
df_money=df_movies[["movie_title","director_name","budget","gross","ganancias"]]
df_money.head()
# Out:
#                                   movie_title      director_name       budget  \
# 0                                      Avatar      James Cameron  237000000.0
# 1    Pirates of the Caribbean: At World's End     Gore Verbinski  300000000.0
# 2                                     Spectre         Sam Mendes  245000000.0
# 3                       The Dark Knight Rises  Christopher Nolan  250000000.0
# 4  Star Wars: Episode VII - The Force Awakens        Doug Walker          NaN
#
#          gross    ganancias
# 0  760505847.0  523505847.0
# 1  309404152.0    9404152.0
# 2  200074175.0  -44925825.0
# 3  448130642.0  198130642.0
# 4          NaN          NaN

# %% [markdown]
# ### Ejercicio 18
# A partir de df_money muestre cuáles son las 10 películas con mayores ganancias? Guárdelo en df_topten_movies, grabe los datos en un archivo dentro de la carpeta "datos" con el nombre "Ejericio18.csv" y muestre los resultados.

# %%
df_topten_movies= df_money.sort_values("ganancias", ascending=False).head(10)
df_topten_movies.to_csv("datos/Ejericio18.csv")
df_topten_movies
# Out:
#                                     movie_title      director_name  \
# 0                                        Avatar      James Cameron
# 29                               Jurassic World    Colin Trevorrow
# 26                                      Titanic      James Cameron
# 2973         Star Wars: Episode IV - A New Hope       George Lucas
# 3028                 E.T. the Extra-Terrestrial   Steven Spielberg
# 17                                 The Avengers        Joss Whedon
# 503                               The Lion King       Roger Allers
# 237   Star Wars: Episode I - The Phantom Menace       George Lucas
# 66                              The Dark Knight  Christopher Nolan
# 433                            The Hunger Games          Gary Ross
#
#            budget        gross    ganancias
# 0     237000000.0  760505847.0  523505847.0
# 29    150000000.0  652177271.0  502177271.0
# 26    200000000.0  658672302.0  458672302.0
# 2973   11000000.0  460935665.0  449935665.0
# ...

# %% [markdown]
# ### Ejercicio 19
#
# El directivo de una compañía cinematográfica quiere saber cuáles son las ganancias promedio que puede esperar obtener con una nueva película. Guarde el resultado en la variable prom_ganancias y muestre el resultado

# %%
# Escriba aquí su código
prom_ganancias= df_movies.ganancias.mean()
prom_ganancias
print(f"Las ganancias promedio que puede esperar obtener de una pelicula es de {format(prom_ganancias,'0.2f')}")
# Out:
# Las ganancias promedio que puede esperar obtener de una pelicula es de 8693209.48

# %% [markdown]
# ### Ejercicio 20
# A partir del DataFrame df_topten_movies del ejercicio 18:
# * Realice un gráfico de líneas con los datos del DataFrame.
# * Defina la columna movie_title como índice del DataFrame.
# * El gráfico debe tener el título: "Películas con mayor ganancia".
# * Configure la leyenda para que se visualice en la parte superior derecha.
# * Asignele al gráfico una rejilla o grilla para las coordenadas x e y.
# * Guarde el gráfico, en la carpeta "datos", en un archivo: "Ejercicio20.png"
# * Muestre el gráfico

# %%
df_topten_movies = df_topten_movies.set_index('movie_title')
fig, eje= mp.subplots()
df_topten_movies.plot(ax=eje)
eje.set_title("Películas con mayor ganancia")
eje.legend(loc="upper right")
eje.grid(axis = 'x', color = 'red', linestyle = 'dashed')
eje.grid(axis = 'y', color = 'green', linestyle = 'dashed')
mp.savefig("datos/Ejercicio20.png")
mp.show()
