# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: 70CC-A66C
#
#  Directorio de C:\Users\Alumno\clase 4-05
#
# 04/05/2022  22:21    <DIR>          .
# 04/05/2022  22:21    <DIR>          ..
# 04/05/2022  20:17    <DIR>          .ipynb_checkpoints
# 04/05/2022  22:21            72.138 Wine quality.ipynb
#                1 archivos         72.138 bytes
#                3 dirs  34.371.641.344 bytes libres

# %%
cd ..
# Out:
# C:\Users\Alumno

# %%
df= pd.read_csv('winequality-white.csv', sep=';')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df.quality.unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %%
train,test= train_test_split(df, test_size=0.2,random_state=123)
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4120            7.4              0.28         0.50            12.1      0.049
# 1169            7.5              0.14         0.34             1.3      0.055
# 1941            6.8              0.31         0.32             7.6      0.052
# 1971            6.3              0.41         0.30             3.2      0.030
# 3124            6.5              0.24         0.39            17.3      0.052
# ...             ...               ...          ...             ...        ...
# 1593            8.6              0.16         0.49             7.3      0.043
# 4060            6.4              0.41         0.01             6.1      0.048
# 1346            7.0              0.46         0.39             6.2      0.039
# 3454            5.8              0.54         0.00             1.4      0.033
# 3582            6.3              0.32         0.32             1.5      0.037
#
# ...

# %%
test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1088            7.4              0.20         0.37           16.95      0.048
# 4366            5.9              0.29         0.28            3.20      0.035
# 92              6.9              0.24         0.33            1.70      0.035
# 2901            6.5              0.22         0.32            2.20      0.028
# 2330            7.5              0.38         0.29           12.70      0.050
# ...             ...               ...          ...             ...        ...
# 4189            6.4              0.21         0.21            5.10      0.097
# 3341            7.6              0.17         0.27            4.60      0.050
# 1055            8.6              0.26         0.41            2.20      0.049
# 3114            6.3              0.17         0.32            4.20      0.040
# 654             6.5              0.21         0.37            2.50      0.048
#
# ...

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
x= df.drop(["quality"], axis=1)
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
y= df.quality
y
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 4893    6
# 4894    5
# 4895    6
# 4896    7
# 4897    6
# Name: quality, Length: 4898, dtype: int64

# %%
train_x,test_x,train_y,test_y= train_test_split(x,y, test_size=0.2,random_state=123)

# %%
train_x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4120            7.4              0.28         0.50            12.1      0.049
# 1169            7.5              0.14         0.34             1.3      0.055
# 1941            6.8              0.31         0.32             7.6      0.052
# 1971            6.3              0.41         0.30             3.2      0.030
# 3124            6.5              0.24         0.39            17.3      0.052
# ...             ...               ...          ...             ...        ...
# 1593            8.6              0.16         0.49             7.3      0.043
# 4060            6.4              0.41         0.01             6.1      0.048
# 1346            7.0              0.46         0.39             6.2      0.039
# 3454            5.8              0.54         0.00             1.4      0.033
# 3582            6.3              0.32         0.32             1.5      0.037
#
# ...

# %%
modelo=DecisionTreeClassifier(random_state=123, max_depth=4)
modelo.fit(train_x,train_y)
pred_y=modelo.predict(test_x)

# %%
from sklearn.metrics import accuracy_score
acc= accuracy_score(test_y,pred_y)
acc
# Out:
# 0.5418367346938775

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=20,weights="distance")
knn.fit(train_x,train_y)
predknn_y=knn.predict(test_x)
ac= accuracy_score(test_y,predknn_y)
ac
# Out:
# 0.6071428571428571

# %%
pip install dtale
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import dtale

# %%
d=dtale.show(df)
d.open_browser()

# %%
n_range= range(5,100)
list=[]
for n in n_range:
    knn=KNeighborsClassifier(n_neighbors=n)
    knn.fit(train_x,train_y)
    predknn_y=knn.predict(test_x)
    ac= accuracy_score(test_y,predknn_y)
    x=x+1
print(ac)
# Out:
# 0.47346938775510206

# %%
n_range= range(5,100)
list=[]
for n in n_range:
    knn=KNeighborsClassifier(n_neighbors=n,weights="distance")
    knn.fit(train_x,train_y)
    predknn_y=knn.predict(test_x)
    ac= accuracy_score(test_y,predknn_y)
    x=x+1
print(ac)
# Out:
# 0.6377551020408163

# %%
list(range(0,10))
