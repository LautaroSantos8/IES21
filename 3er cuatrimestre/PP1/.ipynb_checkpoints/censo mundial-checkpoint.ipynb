# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\Usuario\\Desktop\\ies 21\\3er semestre\\Practica Profecional 1'

# %%
ls
# Out:
#  El volumen de la unidad C es Windows
#  El n£mero de serie del volumen es: 165F-27AD
#
#  Directorio de C:\Users\Usuario\Desktop\ies 21\3er semestre\Practica Profecional 1
#
# 05/05/2022  22:06    <DIR>          .
# 05/05/2022  22:06    <DIR>          ..
# 28/04/2022  18:45    <DIR>          .ipynb_checkpoints
# 05/05/2022  22:06            49.292 censo mundial.ipynb
# 04/05/2022  14:44    <DIR>          Practicas-profecionales
# 28/04/2022  18:25         5.511.795 WPP2019_TotalPopulationBySex.rar
#                2 archivos      5.561.087 bytes
#                4 dirs  166.411.816.960 bytes libres

# %%
cd Practicas-profecionales
# Out:
# C:\Users\Usuario\Desktop\ies 21\3er semestre\Practica Profecional 1\Practicas-profecionales

# %%
ls
# Out:
#  El volumen de la unidad C es Windows
#  El n£mero de serie del volumen es: 165F-27AD
#
#  Directorio de C:\Users\Usuario\Desktop\ies 21\3er semestre\Practica Profecional 1\Practicas-profecionales
#
# 04/05/2022  14:44    <DIR>          .
# 04/05/2022  14:44    <DIR>          ..
# 04/05/2022  14:42            15.033 censo mundial.ipynb
# 12/04/2020  10:48        22.383.021 WPP2019_TotalPopulationBySex.csv
#                2 archivos     22.398.054 bytes
#                2 dirs  166.411.816.960 bytes libres

# %%
datos= pd.read_csv("C:\\Users\\Usuario\\Desktop\\ies 21\\3er semestre\\Practica Profecional 1\Practicas-profecionales\WPP2019_TotalPopulationBySex.csv",encoding = "utf-8")
df= pd.DataFrame(datos)
df
# Out:
#         LocID     Location  VarID      Variant  Time  MidPeriod    PopMale  \
# 0           4  Afghanistan      2       Medium  1950     1950.5   4099.243
# 1           4  Afghanistan      2       Medium  1951     1951.5   4134.756
# 2           4  Afghanistan      2       Medium  1952     1952.5   4174.450
# 3           4  Afghanistan      2       Medium  1953     1953.5   4218.336
# 4           4  Afghanistan      2       Medium  1954     1954.5   4266.484
# ...       ...          ...    ...          ...   ...        ...        ...
# 280927    716     Zimbabwe    207  Lower 95 PI  2080     2080.5  10576.533
# 280928    716     Zimbabwe    207  Lower 95 PI  2085     2085.5  10293.349
# 280929    716     Zimbabwe    207  Lower 95 PI  2090     2090.5   9920.336
# 280930    716     Zimbabwe    207  Lower 95 PI  2095     2095.5   9503.711
# 280931    716     Zimbabwe    207  Lower 95 PI  2100     2100.5   9090.075
#
#         PopFemale   PopTotal  PopDensity
# ...

# %% [markdown]
# ### Los paises con datos faltantes son los siguientes:

# %%
# paises con datos faltantes
datosNulos= df[df.isnull().any(axis=1)]
datosNulos.Location.unique()
# Out:
# array(['American Samoa', 'Andorra', 'Anguilla', 'Bermuda',
#        'Bonaire, Sint Eustatius and Saba', 'British Virgin Islands',
#        'Cayman Islands', 'Cook Islands', 'Dominica',
#        'Falkland Islands (Malvinas)', 'Faroe Islands', 'Gibraltar',
#        'Greenland', 'Holy See', 'Isle of Man', 'Liechtenstein',
#        'Marshall Islands', 'Monaco', 'Montserrat', 'Nauru', 'Niue',
#        'Northern Mariana Islands', 'Palau', 'Saint Barthélemy',
#        'Saint Helena', 'Saint Kitts and Nevis',
#        'Saint Martin (French part)', 'Saint Pierre and Miquelon',
#        'San Marino', 'Sint Maarten (Dutch part)', 'Tokelau',
#        'Turks and Caicos Islands', 'Tuvalu', 'Wallis and Futuna Islands'],
#       dtype=object)

# %% [markdown]
# ### Tasa de crecimiento poblacional anual media para todos los países en el intervalo 2000-2020

# %%
#obtengo los datos del periodo 2000-2020
list1= range(2000,2021)
dfanio= df[df.Time.isin(list1)]
dfanio
# Out:
#         LocID     Location  VarID      Variant  Time  MidPeriod    PopMale  \
# 50          4  Afghanistan      2       Medium  2000     2000.5  10689.508
# 51          4  Afghanistan      2       Medium  2001     2001.5  11117.754
# 52          4  Afghanistan      2       Medium  2002     2002.5  11642.106
# 53          4  Afghanistan      2       Medium  2003     2003.5  12214.634
# 54          4  Afghanistan      2       Medium  2004     2004.5  12763.726
# ...       ...          ...    ...          ...   ...        ...        ...
# 280847    716     Zimbabwe    202    Median PI  2020     2020.5   7092.010
# 280864    716     Zimbabwe    203  Upper 80 PI  2020     2020.5   7092.010
# 280881    716     Zimbabwe    204  Lower 80 PI  2020     2020.5   7092.010
# 280898    716     Zimbabwe    206  Upper 95 PI  2020     2020.5   7092.010
# 280915    716     Zimbabwe    207  Lower 95 PI  2020     2020.5   7092.010
#
#         PopFemale   PopTotal  PopDensity
# ...

# %%
anios= 2020-2000
CrecimientoPobl= [((dfanio.PopTotal.max()-dfanio.PopTotal.min())**(1/anios))-1]*100
CrecimientoPobl[0]
# Out:
# 1.2110076392013664

# %%
if dfanio[dfanio["Location"]]== dfanio[dfanio["Location"]]:
    print(dfanio)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-d59abb37f2d0> in <module>
# ----> 1 if dfanio[dfanio["Location"]]== dfanio[dfanio["Location"]]:
#       2     print(dfanio)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ...

# %%
menor= dfanio[dfanio["Location"]=='Afghanistan']
menor
# Out:
#      LocID     Location  VarID              Variant  Time  MidPeriod  \
# 50       4  Afghanistan      2               Medium  2000     2000.5
# 51       4  Afghanistan      2               Medium  2001     2001.5
# 52       4  Afghanistan      2               Medium  2002     2002.5
# 53       4  Afghanistan      2               Medium  2003     2003.5
# 54       4  Afghanistan      2               Medium  2004     2004.5
# 55       4  Afghanistan      2               Medium  2005     2005.5
# 56       4  Afghanistan      2               Medium  2006     2006.5
# 57       4  Afghanistan      2               Medium  2007     2007.5
# 58       4  Afghanistan      2               Medium  2008     2008.5
# 59       4  Afghanistan      2               Medium  2009     2009.5
# 60       4  Afghanistan      2               Medium  2010     2010.5
# 61       4  Afghanistan      2               Medium  2011     2011.5
# 62       4  Afghanistan      2               Medium  2012     2012.5
# ...
