# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %% [markdown]
# ### Ejercicio 5:
# Podría repetir el ejericio 3 visto anteriormente:
#
# Dado el DataFrame dfC:
#
# - En las columnas A y C, impute a los valores -1, el promedio.
# - En las columnas B y D impute a los valores -1 la mediana.
#
# Guarde los resutados en un nuevo DataFrame denominado dfC_Transformado2

# %%
dfC=pd.DataFrame([[3,7,-1,0],[2,-1,5,4],[0,0,0,0],[-1,5,4,2],[2,6,8,1],[2,1,3,2]])
dfC.columns=['A','B','C','D']
dfC
# Out:
#    A  B  C  D
# 0  3  7 -1  0
# 1  2 -1  5  4
# 2  0  0  0  0
# 3 -1  5  4  2
# 4  2  6  8  1
# 5  2  1  3  2

# %%
T1 = ('trannsform_Mean',SimpleImputer(strategy='mean'),['A','C'])
T2 = ('trannsform_Median',SimpleImputer(strategy='median'),['B','D'])
Transformador= ColumnTransformer(transformers=[T1,T2],remainder='passthrough')
Transformador.fit(dfC)
C_transformado = Transformador.transform(dfC)
dfC_Transformado2 = pd.DataFrame(C_transformado, columns = dfC.columns)
dfC_Transformado2
# Out:
#      A    B    C    D
# 0  3.0 -1.0  7.0  0.0
# 1  2.0  5.0 -1.0  4.0
# 2  0.0  0.0  0.0  0.0
# 3 -1.0  4.0  5.0  2.0
# 4  2.0  8.0  6.0  1.0
# 5  2.0  3.0  1.0  2.0

# %% [markdown]
# #### Ejercicio 6
# Supongamos que contamos con el DataFrame dfE:

# %%
dfE=pd.DataFrame([[1.5,'Si',2,True],[4,'No',7,False],[np.nan,'Si',9,True],[3.5,np.nan,8,np.nan],[6,'Si',np.nan,True]])
dfE.columns=['x1','x2','x3','x4']
dfE
# Out:
#     x1   x2   x3     x4
# 0  1.5   Si  2.0   True
# 1  4.0   No  7.0  False
# 2  NaN   Si  9.0   True
# 3  3.5  NaN  8.0    NaN
# 4  6.0   Si  NaN   True

# %% [markdown]
# y queremos imputar:
# - el **promedio** a las numéricas y,
# - la **moda** a las categóricas, de texto y booleanas,
# - el resultado lo queremos en el DataFrame denominado dfE_Transformado

# %%
cols_num=dfE.select_dtypes(np.number).columns
cols_num
# Out:
# pandas.core.indexes.base.Index

# %%
cols_cat=dfE.select_dtypes(include=['object','bool']).columns
cols_cat
# Out:
# Index(['x2', 'x4'], dtype='object')

# %%
t1 = ('Imputer_num', SimpleImputer(strategy='mean'),list(cols_num))
t2 = ('Imputer_cat', SimpleImputer(strategy='most_frequent'),list(cols_cat))
transformadas = ColumnTransformer(transformers=[t1,t2],remainder='passthrough')
transformadas.fit(dfE)
E_Transformado= transformadas.transform(dfE)
dfE_Transformado = pd.DataFrame(E_Transformado, columns = ['x1','x3','x2','x4'])
dfE_Transformado
# Out:
#      x1   x3  x2     x4
# 0   1.5  2.0  Si   True
# 1   4.0  7.0  No  False
# 2  3.75  9.0  Si   True
# 3   3.5  8.0  Si   True
# 4   6.0  6.5  Si   True
