# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import numpy as np
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Internos activos

# %% [markdown]
# importar y leer contenidos de mi json

# %%
'''
# importo las librerias
import urllib.request, json
import time 
# creo un diccionario vacio
df_internos_activos= pd.DataFrame()
data_json= None
for x in np.arange(0,121,1):
  # a urllib.request.urlopen le paso la url donde se encuentra mi json y lo nombro url
  with urllib.request.urlopen('https://cordobus.apps.cordoba.gob.ar/tracking/api/internos-activos-ahora/?format=json&id_recorrido=955') as url:
  # le cargo esos datos a mi diccionario vacio
    data_json = json.load(url)
  df_internos_activos_1= pd.json_normalize(data_json['results']['features'], max_level=4)
  df_internos_activos=df_internos_activos.append(df_internos_activos_1,ignore_index=True)
  time.sleep(30)
df_internos_activos.to_csv('DataFrame_Colectivos_Geolocalizados.csv')
'''
# Out:
# "\n# importo las librerias\nimport urllib.request, json\nimport time \n# creo un diccionario vacio\ndf_internos_activos= pd.DataFrame()\ndata_json= None\nfor x in np.arange(0,121,1):\n  # a urllib.request.urlopen le paso la url donde se encuentra mi json y lo nombro url\n  with urllib.request.urlopen('https://cordobus.apps.cordoba.gob.ar/tracking/api/internos-activos-ahora/?format=json&id_recorrido=955') as url:\n  # le cargo esos datos a mi diccionario vacio\n    data_json = json.load(url)\n  df_internos_activos_1= pd.json_normalize(data_json['results']['features'], max_level=4)\n  df_internos_activos=df_internos_activos.append(df_internos_activos_1,ignore_index=True)\n  time.sleep(30)\ndf_internos_activos.to_csv('DataFrame_Colectivos_Geolocalizados.csv')\n"

# %%
#df_colectivos=pd.read_csv('c:/Users/Usuario/Desktop/lautaro/ies 21/4to cuatrimestre/AA2/tp_Aprendizaje automatico/DataFrame_Colectivos_Geolocalizados.csv')
#df_colectivos=pd.read_csv('/content/drive/MyDrive/Inteligencia Artificial/segundo año/cuarto/AA2/TP/DataFrame_Colectivos_Geolocalizados.csv')
df_colectivos = pd.read_csv("/content/drive/MyDrive/AA2/tp/DataFrame_Colectivos_Geolocalizados.csv")
df_colectivos.head()
# Out:
#    Unnamed: 0    id     type geometry.type      geometry.coordinates  \
# 0           0   471  Feature         Point   [-64.19503, -31.499508]
# 1           1    69  Feature         Point  [-64.190201, -31.423216]
# 2           2  1073  Feature         Point   [-64.19915, -31.447826]
# 3           3  1103  Feature         Point  [-64.195854, -31.499517]
# 4           4   471  Feature         Point   [-64.19503, -31.499508]
#
#    properties.nombre  properties.linea properties.ultima_posicion_time  \
# 0               2669                51       2022-11-01T12:46:08-03:00
# 1               2708                51       2022-11-01T12:40:40-03:00
# 2               3609                51       2022-11-01T12:46:08-03:00
# 3               3866                51       2022-11-01T12:44:11-03:00
# 4               2669                51       2022-11-01T12:46:08-03:00
#
#    properties.recorrido_actual properties.recorrido_nombre  \
# 0                          955                       reg51
# 1                          955                       reg51
# 2                          955                       reg51
# 3                          955                       reg51
# 4                          955                       reg51
#
#    properties.ultimas_velocidades_promedio  \
# 0                                     11.0
# 1                                     15.0
# 2                                     30.0
# 3                                     42.0
# 4                                     11.0
#
#    properties.ultimas_variaciones_latitud  \
# 0                                0.000078
# 1                                0.008827
# 2                                0.028129
# 3                                0.000046
# 4                                0.000078
#
#    properties.ultimas_variaciones_longitud  properties.adaptado  \
# 0                                 0.007614                False
# 1                                 0.003510                False
# 2                                 0.010528                 True
# 3                                 0.006890                False
# 4                                 0.007614                False
#
#    properties.piso_bajo  properties.articulado  properties.empresa  \
# 0                 False                  False                   2
# 1                 False                  False                   2
# 2                 False                  False                   2
# 3                 False                  False                   2
# 4                 False                  False                   2
#
#   properties.color
# 0          #ff0000
# 1          #ff0000
# 2          #ff0000
# 3          #ff0000
# 4          #ff0000

# %%
df_colectivos=df_colectivos[['id','geometry.coordinates','properties.ultima_posicion_time']]
df_colectivos.head()
# Out:
#      id      geometry.coordinates properties.ultima_posicion_time
# 0   471   [-64.19503, -31.499508]       2022-11-01T12:46:08-03:00
# 1    69  [-64.190201, -31.423216]       2022-11-01T12:40:40-03:00
# 2  1073   [-64.19915, -31.447826]       2022-11-01T12:46:08-03:00
# 3  1103  [-64.195854, -31.499517]       2022-11-01T12:44:11-03:00
# 4   471   [-64.19503, -31.499508]       2022-11-01T12:46:08-03:00

# %%
df_colectivos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 3 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               569 non-null    int64
#  1   geometry.coordinates             569 non-null    object
#  2   properties.ultima_posicion_time  569 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 13.5+ KB

# %%
df = pd.DataFrame()
for x in df_colectivos['geometry.coordinates']:
  string = x
  characters = "[]"
  string = ''.join( x for x in string if x not in characters)
  df=df.append({'coordenada':string},ignore_index=True)
df.head()
# Out:
#                coordenada
# 0   -64.19503, -31.499508
# 1  -64.190201, -31.423216
# 2   -64.19915, -31.447826
# 3  -64.195854, -31.499517
# 4   -64.19503, -31.499508

# %%
df_colectivos=pd.concat([df_colectivos,df],axis=1)

# %%
df_colectivos[['Latitud','Longitud']]=df_colectivos['coordenada'].str.split(',',expand=True)
df_colectivos.drop(['geometry.coordinates','coordenada'],axis=1,inplace=True)
df_colectivos
# Out:
#        id properties.ultima_posicion_time     Latitud     Longitud
# 0     471       2022-11-01T12:46:08-03:00   -64.19503   -31.499508
# 1      69       2022-11-01T12:40:40-03:00  -64.190201   -31.423216
# 2    1073       2022-11-01T12:46:08-03:00   -64.19915   -31.447826
# 3    1103       2022-11-01T12:44:11-03:00  -64.195854   -31.499517
# 4     471       2022-11-01T12:46:08-03:00   -64.19503   -31.499508
# ..    ...                             ...         ...          ...
# 564   816       2022-11-01T13:48:15-03:00  -64.203491   -31.473297
# 565   301       2022-11-01T13:46:59-03:00  -64.191444   -31.426508
# 566  1738       2022-11-01T13:48:20-03:00  -64.188004     -31.4144
# 567   367       2022-11-01T13:43:29-03:00  -64.198494    -31.46352
# 568   398       2022-11-01T13:46:18-03:00  -64.184456   -31.409525
#
# [569 rows x 4 columns]

# %%
df_colectivos[['Latitud','Longitud']]=df_colectivos[['Latitud','Longitud']].astype(float)

# %%
colectivo_fijado=df_colectivos.loc[df_colectivos['id']==69]

# %%
colectivo_fijado # fijarse que el bondi inicialize su recorrido en lacolumna 0 ylofinalice ennla ultima
# Out:
#      id properties.ultima_posicion_time    Latitud   Longitud
# 1    69       2022-11-01T12:40:40-03:00 -64.190201 -31.423216
# 5    69       2022-11-01T12:40:40-03:00 -64.190201 -31.423216
# 9    69       2022-11-01T12:46:41-03:00 -64.196487 -31.439388
# 14   69       2022-11-01T12:46:41-03:00 -64.196487 -31.439388
# 19   69       2022-11-01T12:47:58-03:00 -64.197685 -31.443142
# ..   ..                             ...        ...        ...
# 300  69       2022-11-01T13:15:04-03:00 -64.190903 -31.505146
# 306  69       2022-11-01T13:15:04-03:00 -64.190903 -31.505146
# 312  69       2022-11-01T13:15:04-03:00 -64.190903 -31.505146
# 318  69       2022-11-01T13:15:04-03:00 -64.190903 -31.505146
# 324  69       2022-11-01T13:15:04-03:00 -64.190903 -31.505146
#
# [76 rows x 4 columns]

# %%
colectivo_fijado=colectivo_fijado.drop_duplicates()
colectivo_fijado.head()
# Out:
#     id properties.ultima_posicion_time    Latitud   Longitud
# 1   69       2022-11-01T12:40:40-03:00 -64.190201 -31.423216
# 9   69       2022-11-01T12:46:41-03:00 -64.196487 -31.439388
# 19  69       2022-11-01T12:47:58-03:00 -64.197685 -31.443142
# 27  69       2022-11-01T12:48:55-03:00 -64.198830 -31.446869
# 34  69       2022-11-01T12:49:15-03:00 -64.199081 -31.447590

# %% [markdown]
# ### Paradas

# %%
# importo las librerias
import urllib.request, json
# creo un diccionario vacio
data_json_parada= None
# a urllib.request.urlopen le paso la url donde se encuentra mi json y lo nombro url
with urllib.request.urlopen('https://cordobus.apps.cordoba.gob.ar/paradas-colectivos/api/paradas-colectivos/?format=json&recorrido_id=955') as url:
# le cargo esos datos a mi diccionario vacio
  data_json_parada = json.load(url)
df_paradas= pd.json_normalize(data_json_parada['results']['features'], max_level=4)

# %%
df_paradas.head()
# Out:
#       id     type geometry.type      geometry.coordinates properties.codigo  \
# 0  17366  Feature         Point  [-64.187354, -31.416555]             26436
# 1  17367  Feature         Point  [-64.189559, -31.421682]             26437
# 2  17368  Feature         Point  [-64.191463, -31.426246]             26155
# 3  17369  Feature         Point  [-64.192622, -31.429084]             25679
# 4  17370  Feature         Point   [-64.19385, -31.431835]             25681
#
#    properties.recorrido.id  properties.recorrido.linea.id  \
# 0                      955                             35
# 1                      955                             35
# 2                      955                             35
# 3                      955                             35
# 4                      955                             35
#
#   properties.recorrido.linea.empresa properties.recorrido.linea.troncal  \
# 0                               ERSA                         Troncal 50
# 1                               ERSA                         Troncal 50
# 2                               ERSA                         Troncal 50
# 3                               ERSA                         Troncal 50
# 4                               ERSA                         Troncal 50
#
#   properties.recorrido.linea.nombre_publico properties.recorrido.linea.color  \
# 0                                        51                          #ff0000
# 1                                        51                          #ff0000
# 2                                        51                          #ff0000
# 3                                        51                          #ff0000
# 4                                        51                          #ff0000
#
#   properties.recorrido.descripcion_corta  \
# 0                                  reg51
# 1                                  reg51
# 2                                  reg51
# 3                                  reg51
# 4                                  reg51
#
#   properties.recorrido.descripcion_larga  \
# 0                   A Bº VILLA ANGELELLI
# 1                   A Bº VILLA ANGELELLI
# 2                   A Bº VILLA ANGELELLI
# 3                   A Bº VILLA ANGELELLI
# 4                   A Bº VILLA ANGELELLI
#
#   properties.recorrido.descripcion_cuando_llega  properties.poste.id  \
# 0                   HACIA B° VILLA ANGELELLI II                 3697
# 1                   HACIA B° VILLA ANGELELLI II                 7978
# 2                   HACIA B° VILLA ANGELELLI II                 3485
# 3                   HACIA B° VILLA ANGELELLI II                 3053
# 4                   HACIA B° VILLA ANGELELLI II                 4934
#
#   properties.poste.identificador properties.poste.descripcion
# 0                           None                        C7778
# 1                          C7779                        C7779
# 2                           None                        C7362
# 3                           None                        C6197
# 4                           None                        C6199

# %%
df_paradas=df_paradas[['geometry.coordinates']]
df_paradas
# Out:
#         geometry.coordinates
# 0   [-64.187354, -31.416555]
# 1   [-64.189559, -31.421682]
# 2   [-64.191463, -31.426246]
# 3   [-64.192622, -31.429084]
# 4    [-64.19385, -31.431835]
# 5   [-64.197031, -31.441049]
# 6   [-64.198952, -31.446907]
# 7   [-64.199499, -31.448733]
# 8   [-64.200647, -31.451987]
# 9   [-64.200969, -31.453506]
# 10  [-64.201216, -31.455693]
# 11  [-64.200894, -31.457689]
# 12   [-64.201462, -31.45994]
# 13  [-64.204456, -31.471141]
# 14  [-64.202642, -31.475323]
# 15  [-64.202728, -31.477441]
# 16   [-64.202846, -31.47993]
# 17  [-64.203528, -31.482368]
# 18   [-64.204649, -31.48515]
# 19  [-64.205239, -31.486751]
# 20  [-64.206355, -31.488553]

# %%
df = pd.DataFrame()
for x in df_paradas['geometry.coordinates']:
  string = x
  characters = "[]"
  string = ''.join( x for x in string if x not in characters)
  df=df.append({'coordenada':string},ignore_index=True)
df.head()

# %%
cord_inicial_L=[]
cord_inicial_La=[]
cord_final_L=[]
cord_final_La=[]

for fn in  range(colectivo_fijado.iloc[1:].shape[0]):
  for ini in range(colectivo_fijado.iloc[0:fn].shape[0]):
     cord_inicial_L.append(colectivo_fijado.iloc[ini]["Longitud"])
     cord_final_L.append(colectivo_fijado.iloc[fn]["Longitud"])
     cord_inicial_La.append(colectivo_fijado.iloc[ini]["Latitud"])
     cord_final_La.append(colectivo_fijado.iloc[fn]["Latitud"])
